# %%
import sys 


try:
    1/0
except ZeroDivisionError:
    exc_type, exc_value, exc_traceback = sys.exc_info()
    print(f"Exception type: {exc_type}")
    print(f"Exception value: {exc_value}")
    print(f"Exception traceback: {exc_traceback}")
# Out:
# Exception type: <class 'ZeroDivisionError'>
# Exception value: division by zero
# Exception traceback: <traceback object at 0x109b0f040>

# %%
import sys
import traceback

def divide(a, b):
    try:
        return a / b
    except ZeroDivisionError:
        exc_type, exc_value, exc_traceback = sys.exc_info()
        print(f"Exception type: {exc_type}")
        print(f"Exception value: {exc_value}")
        print("Traceback details:")
        traceback.print_tb(exc_traceback)

divide(1, 0)
# Out:
# Exception type: <class 'ZeroDivisionError'>
# Exception value: division by zero
# Traceback details:
#   File "/var/folders/sr/x0jhwq2j309g1590y9_vgshh0000gn/T/ipykernel_24072/1918705619.py", line 6, in divide
#     return a / b

# %%
from src.exception import CustomException
try:
    x = int("abc")
except Exception as e:
    raise CustomException(e, sys)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from src.exception import CustomException
#       2 try:
#       3     x = int("abc")
#
# ModuleNotFoundError: No module named 'src'

# %%
# !cd ..

# %%
# Out:
# try.ipynb
